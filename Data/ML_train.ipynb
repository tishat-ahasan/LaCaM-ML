# %%
import pandas as pd

# %%
data = pd.read_csv('Supervised/32by32.txt')

# %%
data.head(5)
# Out:
#    obstacle_p   agent_p       a_g      a_ng  d_max  d_min    d_avg     d_std  \
# 0    0.110629  0.032538  0.000000  1.000000     39      1  15.7097  10.22710
# 1    0.110629  0.032538  0.000000  1.000000     38      1  14.8065  10.13270
# 2    0.110629  0.032538  0.033333  0.966667     37      1  14.3000   9.93026
# 3    0.110629  0.032538  0.066667  0.933333     36      1  13.8966   9.66096
# 4    0.110629  0.032538  0.066667  0.933333     35      1  12.9310   9.61655
#
#    c_max  c_min     c_avg     c_std  ng_0  ng_1  ng_2  ng_3  ng_4  y1  y2  y3
# 0      2      0  0.266667  0.512076     0     0     0     7    23   0   0   1
# 1      2      0  0.433333  0.667499     0     0     0     3    27   0   0   1
# 2      2      0  0.466667  0.718022     0     0     0     6    24   0   0   1
# 3      3      0  0.566667  0.919541     0     0     0     7    23   0   0   1
# 4      3      0  0.566667  0.919541     0     0     0     3    27   0   0   1

# %%
data = data.astype(float)

# %%
data['agent'] = data['agent_p']*922

# %%
data.head(5)
# Out:
#    obstacle_p   agent_p       a_g      a_ng  d_max  d_min    d_avg     d_std  \
# 0    0.110629  0.032538  0.000000  1.000000   39.0    1.0  15.7097  10.22710
# 1    0.110629  0.032538  0.000000  1.000000   38.0    1.0  14.8065  10.13270
# 2    0.110629  0.032538  0.033333  0.966667   37.0    1.0  14.3000   9.93026
# 3    0.110629  0.032538  0.066667  0.933333   36.0    1.0  13.8966   9.66096
# 4    0.110629  0.032538  0.066667  0.933333   35.0    1.0  12.9310   9.61655
#
#    c_max  c_min  ...     c_std  ng_0  ng_1  ng_2  ng_3  ng_4   y1   y2   y3  \
# 0    2.0    0.0  ...  0.512076   0.0   0.0   0.0   7.0  23.0  0.0  0.0  1.0
# 1    2.0    0.0  ...  0.667499   0.0   0.0   0.0   3.0  27.0  0.0  0.0  1.0
# 2    2.0    0.0  ...  0.718022   0.0   0.0   0.0   6.0  24.0  0.0  0.0  1.0
# 3    3.0    0.0  ...  0.919541   0.0   0.0   0.0   7.0  23.0  0.0  0.0  1.0
# 4    3.0    0.0  ...  0.919541   0.0   0.0   0.0   3.0  27.0  0.0  0.0  1.0
#
#    agent
# 0   30.0
# 1   30.0
# 2   30.0
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))  # Adjust the figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# ... (previous code for model, data preprocessing, and splitting) ...

# Initialize empty lists to store training loss over epochs
train_loss = []

# Training loop
num_epochs = 1000

for epoch in range(num_epochs):
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs, y_train)
    loss.backward()
    optimizer.step()
    
    # Append the loss to the list
    train_loss.append(loss.item())

# Make predictions
model.eval()
y_pred = model(X_test).detach().numpy()

# Calculate the loss as the average of MSE for y1, y2, and y3
mse_y1 = mean_squared_error(y_test[:, 0], y_pred[:, 0])
mse_y2 = mean_squared_error(y_test[:, 1], y_pred[:, 1])
mse_y3 = mean_squared_error(y_test[:, 2], y_pred[:, 2])
average_loss = (mse_y1 + mse_y2 + mse_y3) / 3

print(f'Mean Squared Error for y1: {mse_y1}')
print(f'Mean Squared Error for y2: {mse_y2}')
print(f'Mean Squared Error for y3: {mse_y3}')
print(f'Average Loss: {average_loss}')

# Plot the training loss
plt.plot(range(num_epochs), train_loss)
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.title('Training Loss Over Epochs')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 6
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
# ----> 6 from sklearn.model_selection import train_test_split
#       8 # ... (previous code for model, data preprocessing, and splitting) ...
#       9
#      10 # Initialize empty lists to store training loss over epochs
#      11 train_loss = []
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# %pip3 install sklearn
# Out:
# UsageError: Line magic function `%pip3` not found.
